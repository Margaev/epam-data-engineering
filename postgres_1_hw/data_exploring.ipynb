# %%
import pandas as pd

# %%
df = pd.read_csv('P9-ConsumerComplaints.csv', low_memory=False)

# %%
df
# Out:
#       Date Received             Product Name  \
# 0        2013-07-29            Consumer Loan
# 1        2013-07-29  Bank account or service
# 2        2013-07-29  Bank account or service
# 3        2013-07-29  Bank account or service
# 4        2013-07-29                 Mortgage
# ...             ...                      ...
# 65494    2015-05-26                 Mortgage
# 65495    2015-05-06                 Mortgage
# 65496    2015-05-20          Debt collection
# 65497    2015-05-06          Debt collection
# 65498    2015-04-27                 Mortgage
#
#                                  Sub Product  \
# 0                               Vehicle loan
# 1                           Checking account
# 2                           Checking account
# 3                           Checking account
# 4                Conventional fixed mortgage
# ...                                      ...
# 65494                         Other mortgage
# 65495                         Other mortgage
# 65496                          I do not know
# 65497  Other (i.e. phone, health club, etc.)
# 65498            Conventional fixed mortgage
#
#                                           Issue  \
# 0                    Managing the loan or lease
# 1                     Using a debit or ATM card
# 2       Account opening, closing, or management
# 3                      Deposits and withdrawals
# 4      Loan servicing, payments, escrow account
# ...                                         ...
# 65494  Loan servicing, payments, escrow account
# 65495  Loan modification,collection,foreclosure
# 65496     Cont'd attempts collect debt not owed
# 65497     Cont'd attempts collect debt not owed
# 65498  Application, originator, mortgage broker
#
#                                Sub Issue  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 65494                                NaN
# 65495                                NaN
# 65496  Debt resulted from identity theft
# 65497                   Debt is not mine
# 65498                                NaN
#
#                             Consumer Complaint Narrative  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65494                                                NaN
# 65495                                                NaN
# 65496  My identity was stolen back in XXXX 2008 when ...
# 65497                                                NaN
# 65498  Previous lender ( XXXX ) offered mortgage rate...
#
#                                  Company Public Response  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65494                                                NaN
# 65495                                                NaN
# 65496   Company chooses not to provide a public response
# 65497                                                NaN
# 65498  Company believes the complaint is the result o...
#
#                                 Company State Name Zip Code            Tags  \
# 0                 Wells Fargo & Company         VA    24540             NaN
# 1                 Wells Fargo & Company         CA    95992  Older American
# 2                     Santander Bank US         NY    10065             NaN
# 3                 Wells Fargo & Company         GA    30084             NaN
# 4            Franklin Credit Management         CT     6106             NaN
# ...                                 ...        ...      ...             ...
# 65494               Nationstar Mortgage         TX    75401   Servicemember
# 65495                   Bank of America         CA    92880             NaN
# 65496  Performant Financial Corporation         FL    322XX             NaN
# 65497                        Afni, Inc.         CA    92065             NaN
# 65498                      USAA Savings         OR    972XX             NaN
#
#       Consumer Consent Provided Submitted via Date Sent to Company  \
# 0                           NaN         Phone           2013-07-30
# 1                           NaN           Web           2013-07-31
# 2                           NaN           Fax           2013-07-31
# 3                           NaN           Web           2013-07-30
# 4                           NaN           Web           2013-07-30
# ...                         ...           ...                  ...
# 65494                       NaN      Referral           2015-05-29
# 65495                       NaN      Referral           2015-05-07
# 65496          Consent provided           Web           2015-05-20
# 65497                       NaN         Phone           2015-05-07
# 65498          Consent provided           Web           2015-04-27
#
#           Company Response to Consumer Timely Response Consumer Disputed  \
# 0              Closed with explanation             Yes                No
# 1              Closed with explanation             Yes                No
# 2                               Closed             Yes                No
# 3              Closed with explanation             Yes                No
# 4              Closed with explanation             Yes                No
# ...                                ...             ...               ...
# 65494          Closed with explanation             Yes                No
# 65495          Closed with explanation             Yes               Yes
# 65496  Closed with non-monetary relief             Yes                No
# 65497          Closed with explanation             Yes                No
# 65498          Closed with explanation             Yes                No
#
#        Complaint ID
# 0            468882
# 1            468889
# 2            468879
# 3            468949
# 4            475823
# ...             ...
# 65494       1393114
# 65495       1364367
# 65496       1385089
# 65497       1363039
# 65498       1348370
#
# [65499 rows x 18 columns]

# %%
df.iloc[0]
# Out:
# Date Received                                   2013-07-29
# Product Name                                 Consumer Loan
# Sub Product                                   Vehicle loan
# Issue                           Managing the loan or lease
# Sub Issue                                              NaN
# Consumer Complaint Narrative                           NaN
# Company Public Response                                NaN
# Company                              Wells Fargo & Company
# State Name                                              VA
# Zip Code                                             24540
# Tags                                                   NaN
# Consumer Consent Provided                              NaN
# Submitted via                                        Phone
# Date Sent to Company                            2013-07-30
# Company Response to Consumer       Closed with explanation
# Timely Response                                        Yes
# Consumer Disputed                                       No
# Complaint ID                                        468882
# Name: 0, dtype: object

# %%
df.dtypes
# Out:
# Date Received                   object
# Product Name                    object
# Sub Product                     object
# Issue                           object
# Sub Issue                       object
# Consumer Complaint Narrative    object
# Company Public Response         object
# Company                         object
# State Name                      object
# Zip Code                        object
# Tags                            object
# Consumer Consent Provided       object
# Submitted via                   object
# Date Sent to Company            object
# Company Response to Consumer    object
# Timely Response                 object
# Consumer Disputed               object
# Complaint ID                     int64
# dtype: object

# %%
from datetime import datetime
dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d')

# %%
df_types = pd.read_csv('P9-ConsumerComplaints.csv', parse_dates=['Date Received'], date_parser=dateparse)
# Out:
# /home/amargaev/tools/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (5,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_types.shape
# Out:
# (65499, 18)

# %%
df_types.dtypes
# Out:
# Date Received                   datetime64[ns]
# Product Name                            object
# Sub Product                             object
# Issue                                   object
# Sub Issue                               object
# Consumer Complaint Narrative            object
# Company Public Response                 object
# Company                                 object
# State Name                              object
# Zip Code                                object
# Tags                                    object
# Consumer Consent Provided               object
# Submitted via                           object
# Date Sent to Company                    object
# Company Response to Consumer            object
# Timely Response                         object
# Consumer Disputed                       object
# Complaint ID                             int64
# dtype: object

# %%
types = pd.DataFrame([df_types.iloc[:,i].apply(type).value_counts() for i in range(df.shape[1])])
types
# Out:
#                               <class 'pandas._libs.tslibs.timestamps.Timestamp'>  \
# Date Received                                                           65499.0
# Product Name                                                                NaN
# Sub Product                                                                 NaN
# Issue                                                                       NaN
# Sub Issue                                                                   NaN
# Consumer Complaint Narrative                                                NaN
# Company Public Response                                                     NaN
# Company                                                                     NaN
# State Name                                                                  NaN
# Zip Code                                                                    NaN
# Tags                                                                        NaN
# Consumer Consent Provided                                                   NaN
# Submitted via                                                               NaN
# Date Sent to Company                                                        NaN
# Company Response to Consumer                                                NaN
# Timely Response                                                             NaN
# Consumer Disputed                                                           NaN
# Complaint ID                                                                NaN
#
#                               <class 'str'>  <class 'float'>  <class 'int'>
# Date Received                           NaN              NaN            NaN
# Product Name                        65499.0              NaN            NaN
# Sub Product                         46935.0          18564.0            NaN
# Issue                               65499.0              NaN            NaN
# Sub Issue                           30658.0          34841.0            NaN
# Consumer Complaint Narrative         2614.0          62885.0            NaN
# Company Public Response              2450.0          63049.0            NaN
# Company                             65499.0              NaN            NaN
# State Name                          65021.0            478.0            NaN
# Zip Code                            65021.0            478.0            NaN
# Tags                                 9681.0          55818.0            NaN
# Consumer Consent Provided            4760.0          60739.0            NaN
# Submitted via                       65499.0              NaN            NaN
# Date Sent to Company                65499.0              NaN            NaN
# Company Response to Consumer        65499.0              NaN            NaN
# Timely Response                     65499.0              NaN            NaN
# Consumer Disputed                   64391.0           1108.0            NaN
# Complaint ID                            NaN              NaN        65499.0

# %%
x = df_types.iloc[65497, 4]
print(x)
print(type(x))
# Out:
# Debt is not mine
# <class 'str'>

# %%
df.isna().sum()
# Out:
# Date Received                       0
# Product Name                        0
# Sub Product                     18564
# Issue                               0
# Sub Issue                       34841
# Consumer Complaint Narrative    62885
# Company Public Response         63049
# Company                             0
# State Name                        478
# Zip Code                          478
# Tags                            55818
# Consumer Consent Provided       60739
# Submitted via                       0
# Date Sent to Company                0
# Company Response to Consumer        0
# Timely Response                     0
# Consumer Disputed                1108
# Complaint ID                        0
# dtype: int64

# %%
df_types.loc[:, 'Sub Issue'].isna().sum()
# Out:
# 34841

# %%
types.idxmax(axis=1)
# Out:
# Date Received                   <class 'pandas._libs.tslibs.timestamps.Timesta...
# Product Name                                                        <class 'str'>
# Sub Product                                                         <class 'str'>
# Issue                                                               <class 'str'>
# Sub Issue                                                         <class 'float'>
# Consumer Complaint Narrative                                      <class 'float'>
# Company Public Response                                           <class 'float'>
# Company                                                             <class 'str'>
# State Name                                                          <class 'str'>
# Zip Code                                                            <class 'str'>
# Tags                                                              <class 'float'>
# Consumer Consent Provided                                         <class 'float'>
# Submitted via                                                       <class 'str'>
# Date Sent to Company                                                <class 'str'>
# Company Response to Consumer                                        <class 'str'>
# Timely Response                                                     <class 'str'>
# Consumer Disputed                                                   <class 'str'>
# Complaint ID                                                        <class 'int'>
# dtype: object

# %%
df_types.loc[df_types['Product Name'] == 'Prepaid card'].loc[:, 'Timely Response'].loc[df_types['Timely Response'] == 'Yes'].count()
# Out:
# 186

# %%
df_types.loc[:, 'Issue'].isna().sum()
# Out:
# 0
